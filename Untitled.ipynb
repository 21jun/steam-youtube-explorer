# %%
from gensim.models import Word2Vec
from database.pymysql_conn import DataBase
import pandas as pd
import numpy as np
import re
from sklearn.decomposition import PCA
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
db = DataBase()

# %%
SQL = "SELECT CONCAT(gameName, ' ' ,text) as corpus FROM steam.yt_comment where filter=1;"
SQL = "SELECT gameName ,text FROM steam.yt_comment where filter=1;"

# %%
df = db.to_df(SQL)

# %%
df
# Out:
#                                    gameName  \
# 0       DEAD OR ALIVE Xtreme Venus Vacation
# 1       DEAD OR ALIVE Xtreme Venus Vacation
# 2       DEAD OR ALIVE Xtreme Venus Vacation
# 3       DEAD OR ALIVE Xtreme Venus Vacation
# 4       DEAD OR ALIVE Xtreme Venus Vacation
# ...                                     ...
# 451444                          OVR Toolkit
# 451445                          OVR Toolkit
# 451446                          OVR Toolkit
# 451447                          OVR Toolkit
# 451448                          OVR Toolkit
#
#                                                      text
# 0       "Game not available in your region." goddamnit...
# 1       There's more to this game that they didn't exp...
# 2                       What in the world is this song? ?
# 3       I was waiting for Arin to make a joke along th...
# 4       I'm literally screaming because of the single ...
# ...                                                   ...
# ...

# %%
def clean_text(text):
    t = re.sub('[^a-zA-Z0-9]',' ', text).strip()
    t = re.sub(' +', ' ', t)
    return t

# %%
comments = df['text'].apply(clean_text).str.split().to_numpy()

# %%
gameName = df['gameName'].to_numpy()

# %%
corpus = []
for g, c  in zip(gameName, comments):
    text = [g] + c
    corpus.append(text)

# %%
embedding_model = Word2Vec(corpus, size=100,
                           window=5, min_count=50, workers=16, iter=2, sg=1)

# %%
print(embedding_model.most_similar(positive=["DEAD OR ALIVE Xtreme Venus Vacation"], topn=100))
# Out:
# [('Fantasy Girl', 0.7846871614456177), ('帝国与文明', 0.7301684021949768), ('Lovers of Aether', 0.6988985538482666), ('Idle Cooking Emperor', 0.6714871525764465), ('Furry Girl', 0.6678961515426636), ('Monster Girl Island Prologue', 0.6638537645339966), ('missed messages', 0.6411027908325195), ('人间 The Lost We Lost', 0.6395302414894104), ('Pro Cycling Manager 2019', 0.6370736360549927), ('Idle Guardians', 0.6289694905281067), ('Children of Morta Demo', 0.6213170289993286), ('Transformice Adventures Demo', 0.6157848834991455), ('Sankaku Renai Love Triangle Trouble', 0.6156391501426697), ('Bow', 0.6148245334625244), ('Furry', 0.6147164106369019), ('SpiderMan Far From Home Virtual Reality', 0.6054213047027588), ('HARDCORE MECHA', 0.6004593372344971), ('Dan', 0.5999061465263367), ('Hyper', 0.5938004851341248), ('Totally Reliable Delivery Service Beta', 0.5885165929794312), ('YES', 0.5848164558410645), ('LP', 0.5810878872871399), ('Sweden', 0.5810741186141968), ('GT', 0.580060601234436), ('FIVE
# ...

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]
        
    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]
    
    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)

# %%
display_pca_scatterplot(embedding_model, 
                       ["DEAD OR ALIVE Xtreme Venus Vacation","MASS Builder Demo","Winning Post 9","Assassins Creed III Remastered","Lovers of Aether","Borderlands GOTY Enhanced","SUPER DRAGON BALL HEROES WORLD MISSION","Phoenix Wright Ace Attorney Trilogy 逆転裁判123 成歩堂セレクション","Sin Slayers The First Sin","模拟帝国","帝国与文明","模拟帝国 Sim Empire","Paper Dolls Original","Ultra Savage","Furry Girl","Idle Cooking Emperor","人间 The Lost We Lost","AVA Dog Tag","STAR WARS Battlefront Classic 2004","Splitgate Arena Warfare Beta","Neon Beats","Endless World Demo","Puyo Puyo Champions ぷよぷよ eスポーツ","Transformice Adventures Demo","Idle Guardians","Energy Engine PC Live Wallpaper","Battle for the Galaxy","The Defender Farm and Castle","Neon Boost","Otakus Adventure","FIVE NIGHTS AT FREDDYS VR HELP WANTED","Cricket Captain 2019","missed messages","SteamWorld Quest Hand of Gilgamech","Sankaku Renai Love Triangle Trouble","Kao the Kangaroo Round 2","MotoGP19","Quake II RTX","コイカツ Koikatsu Party","SpaceEngine","Project Zero Deaths","HomeWork Is Crazy 作业疯了","Monster Girl Island Prologue","Children of Morta Demo","Fantasy Girl","Esports Life Tycoon","Dark Swords","御龙在天平衡国战版","Totally Reliable Delivery Service Beta","pact with a witch","SpiderMan Far From Home Virtual Reality","HARDCORE MECHA","Pro Cycling Manager 2019","OVR Toolkit"])
# Out:
# <ipython-input-70-d361be361cda>:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   word_vectors = np.array([model[w] for w in words])
# <img src="data:image/png;base64,..." width="600">
